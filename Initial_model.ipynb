# %% [markdown]
# <a href="https://colab.research.google.com/github/Daniaarav2005/CoinSage/blob/main/Initial_model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install emoji
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 590.6/590.6 kB 7.5 MB/s eta 0:00:00
# ...

# %%
import pandas as pd
eth = pd.read_csv('Tweets-Dogecoin.csv')
eth
# Out:
#               date      time  timezone        username  \
# 0       20-04-2021  17:57:09       530     sunnyepposo
# 1       20-04-2021  17:57:07       530        pickndng
# 2       20-04-2021  17:57:07       530    s4y4n9_semu4
# 3       20-04-2021  17:57:06       530     dogecoinsky
# 4       20-04-2021  17:57:04       530     dogeman0401
# ...            ...       ...       ...             ...
# 250004  16-04-2021  06:01:13       530         rwied44
# 250005  16-04-2021  06:01:12       530          rtx933
# 250006  16-04-2021  06:01:12       530     grababagceo
# 250007  16-04-2021  06:01:11       530    rizedogecoin
# 250008  16-04-2021  06:01:10       530  thehandiimanaz
#
#                                          name  \
# 0                                  congrats ✨
# 1       andrea || busy sa exams at pts kuno🍀✨
# 2                             #SayangiSemesta
# 3                                 dogecoinsky
# 4                                         jay
# ...

# %%
import re
for b in range(len(eth['tweet'])):
  try:
    text = eth['tweet'][b]

    #filtering out links
    text = re.sub(r'https?://\S+|www\.\S+', '.', text)
    text = re.sub(r'\\n','',text)
    text = re.sub(r'\b[^\s]*\.com[^\s]*\b','',text)
    text = re.sub(r'\b[^\s]*\.net[^\s]*\b','',text)
    text = re.sub(r'\b[^\s]*\.org[^\s]*\b','',text)
    text = re.sub(r'\b[^\s]*\.gov[^\s]*\b','',text)


    text= re.sub(r'\.','. ',text) #converts ... or .., etc into .
    text = re.sub("[^A-Za-z0-9$,#%!\)\(—.;:'\"\&/ =\+-]","",text) #removes anything that is not within the specified characters
    text = re.sub(r' +',' ', text)
    text = text.strip()
    text = text.lower()
    eth['tweet'][b] = text
  except:
    print(b, eth['tweet'][b])
    eth = eth.drop(b)
eth.reset_index(inplace=True,drop = True)
# Out:
# Streaming output truncated to the last 5000 lines.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   eth['tweet'][b] = text
# <ipython-input-6-6ee9e6186e19>:20: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# ...

# %%
eth.to_csv('cleaned_tweets.csv')

# %%
doge = pd.read_csv('cleaned_tweets.csv')
doge = doge.drop('Unnamed: 0',axis=1)
filtered_doge = doge.loc[doge["language"] == "en",['tweet','date','time']]
filtered_doge.to_csv('filtered_doge.csv')

# %%
filtered_doge
# Out:
#                                                     tweet        date  \
# 0       i invested $16k a couple of weeks ago when a l...  20-04-2021
# 1       bought in for $16k. my #dogecoin will make me ...  20-04-2021
# 2       i invested $16k a couple of weeks ago when a l...  20-04-2021
# 3       looking back in 2010/11, btc had low value, hi...  20-04-2021
# 4       looks like the hype of today isnt coming to fr...  20-04-2021
# ...                                                   ...         ...
# 250003  dogecoinrich there we go!!!! #godoge #dogecoin...  16-04-2021
# 250004                        #dogecoin reaches $0. 20! .  16-04-2021
# 250006  #dogecoin community is unlike any on the plane...  16-04-2021
# 250007                      doge prediction: up #dogecoin  16-04-2021
# 250008  beefsupreme1776 did you read the article to ge...  16-04-2021
#
#             time
# 0       17:57:09
# 1       17:57:07
# 2       17:57:07
# 3       17:57:06
# 4       17:57:04
# ...

# %%
stock = pd.read_csv('/content/Doge_data.csv')
stock['Date'] = pd.to_datetime(stock['Date'])
stock = stock.rename(columns={'Date': 'date', 'Time': 'time',"Open": "open", "High": "high", "Low": "low", "Close": "close"})
stock["net"] = stock["close"] - stock["open"]
filtered_doge['date'] = pd.to_datetime(filtered_doge['date'])
filtered_doge.groupby("date")
stock.groupby("date")

# %%
pd.merge_asof(filtered_doge, stock, on='time', direction='forward')
# Out:
# ---------------------------------------------------------------------------
# MergeError                                Traceback (most recent call last)
# <ipython-input-50-2479b9c8a005> in <cell line: 0>()
# ----> 1 pd.merge_asof(filtered_doge, stock, on='time', direction='forward')
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/reshape/merge.py in merge_asof(left, right, on, left_on, right_on, left_index, right_index, by, left_by, right_by, suffixes, tolerance, allow_exact_matches, direction)
#     689     4 2016-05-25 13:30:00.048   AAPL   98.00       100     NaN     NaN
#     690     """
# --> 691     op = _AsOfMerge(
#     692         left,
#     693         right,
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/reshape/merge.py in __init__(self, left, right, on, left_on, right_on, left_index, right_index, by, left_by, right_by, suffixes, how, tolerance, allow_exact_matches, direction)
#    1997             raise MergeError(msg)
#    1998
# ...

# %%
stock = stock.loc[:,["date","time","net"]]
stock
# Out:
#           date      time     net
# 0   2021-04-16  10:30:00  0.0346
# 1   2021-04-16  11:30:00 -0.0145
# 2   2021-04-16  12:30:00 -0.0043
# 3   2021-04-16  13:30:00  0.0141
# 4   2021-04-16  14:30:00  0.0021
# ..         ...       ...     ...
# 116 2021-04-21  06:30:00 -0.0178
# 117 2021-04-21  07:30:00  0.0098
# 118 2021-04-21  08:30:00  0.0016
# 119 2021-04-21  09:30:00  0.0120
# 120 2021-04-21  10:30:00  0.0081
#
# [121 rows x 3 columns]

# %%
import pandas as pd
pooled_data = pd.read_csv("/content/pooled_data.csv")
pooled_data["net"] = pooled_data["net"].apply(lambda x: 1 if x > 0 else 0)

# %%
pooled_data = pooled_data.sample(frac=1, random_state=42).reset_index(drop=True)
pooled_data = pooled_data.loc[:,["tweet","net"]]
x = pooled_data["tweet"]
y = pooled_data["net"]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.4,random_state=0)
x_valid, x_test = train_test_split(x_test, test_size=0.5, random_state=42)
y_valid, y_test = train_test_split(y_test, test_size=0.5, random_state=42)


# Resetting index for cleaner output
y_valid = y_valid.reset_index(drop=True)
x_valid = x_valid.reset_index(drop=True)
y_test = y_test.reset_index(drop=True)
x_test = x_test.reset_index(drop=True)
y_train = y_train.reset_index(drop=True)
x_train = x_train.reset_index(drop=True)

# %%
y_valid.to_csv('y_valid.csv')
x_valid.to_csv('x_valid.csv')
y_test.to_csv('y_test.csv')
x_test.to_csv('x_test.csv')
x_train.to_csv('x_train.csv')
y_train.to_csv('y_train.csv')

# %%
from transformers import BertTokenizer
tokenizer = BertTokenizer.from_pretrained('bert-base-uncased', do_lower_case=True)
max_len= 256
# Tokenize and encode the sentences
def tokenize_text(texts, tokenizer, max_length=128):
    return tokenizer(
        texts.tolist(),
        padding=True,  # Pad all sequences to the same length
        truncation=True,  # Truncate to max_length if the text is too long
        max_length=max_length,  # Maximum sequence length
        return_tensors='tf',  # Return TensorFlow-compatible tensors
        return_attention_mask=True  # Include attention masks
    )

# Tokenize the texts
inputs = tokenize_text(x_train, tokenizer)

# %%
from transformers import TFBertForSequenceClassification
model = TFBertForSequenceClassification.from_pretrained('bert-base-uncased', num_labels=2)
# Out:
# All PyTorch model weights were used when initializing TFBertForSequenceClassification.
#
# Some weights or buffers of the TF 2.0 model TFBertForSequenceClassification were not initialized from the PyTorch model and are newly initialized: ['classifier.weight', 'classifier.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['binary_accuracy'])

# %%
from tensorflow.keras.callbacks import EarlyStopping
early_stopping = EarlyStopping(min_delta = 0.001,monitor='val_loss', patience=10, restore_best_weights=True)

# %%
import numpy as np
x_t = np.array(x_train.tolist())
y_t = np.array(y_train.tolist())
x_v = np.array(x_valid.tolist())
y_v = np.array(y_valid.tolist())

# %%
trained_model = model.fit(
    [X_train_encoded['input_ids'], X_train_encoded['token_type_ids'], X_train_encoded['attention_mask']],
    y_train,
    validation_data=(
      [X_val_encoded['input_ids'], X_val_encoded['token_type_ids'], X_val_encoded['attention_mask']],y_valid),
    batch_size=128,
    epochs=50,
    verbose = 1
)
# Out:
# Epoch 1/500
# ---------------------------------------------------------------------------
# ResourceExhaustedError                    Traceback (most recent call last)
# <ipython-input-44-935aebcf4acd> in <cell line: 0>()
# ----> 1 trained_model = model.fit(
#       2     [X_train_encoded['input_ids'], X_train_encoded['token_type_ids'], X_train_encoded['attention_mask']],
#       3     y_train,
#       4     validation_data=(
#       5       [X_val_encoded['input_ids'], X_val_encoded['token_type_ids'], X_val_encoded['attention_mask']],y_valid),
#
# /usr/local/lib/python3.11/dist-packages/transformers/modeling_tf_utils.py in fit(self, *args, **kwargs)
#    1227     def fit(self, *args, **kwargs):
#    1228         args, kwargs = convert_batch_encoding(*args, **kwargs)
# -> 1229         return super().fit(*args, **kwargs)
#    1230
#    1231     @functools.wraps(keras.Model.train_on_batch)
#
# ...

# %%
history = pd.DataFrame(model.history)
history.loc[:,[“loss”,”val_loss”]].plot()

# %%
y_train
# Out:
# 0        -0.0326
# 1         0.0175
# 2         0.0099
# 3        -0.0135
# 4         0.0005
#            ...
# 117293    0.0417
# 117294    0.0346
# 117295   -0.0262
# 117296    0.0013
# 117297   -0.0231
# Name: net, Length: 117298, dtype: float64
